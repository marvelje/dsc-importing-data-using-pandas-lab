# %% [markdown]
# # Importing Data Using Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file!
#
# ## Objectives
# You will be able to:
#
# - Use pandas to import data from a CSV and and an Excel spreadsheet
#
# ##  Loading Files with Summary or Meta Data
#
# Load either of the files `'Zipcode_Demos.csv'` or `'Zipcode_Demos.xlsx'`. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled `'Data'`.

# %%
# Import pandas using the standard alias
import pandas as pd
from pandas.io.parsers import ParserError

# %%
# Import the file and print the first 5 rows
df = pd.read_csv('./Data/Zipcode_Demos.csv')
df.head(10)
# Out:
#     0      Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   1                     NaN          0        NaN        NaN        NaN
# 1   2       JURISDICTION NAME    10005.8        NaN        NaN        NaN
# 2   3      COUNT PARTICIPANTS        9.4        NaN        NaN        NaN
# 3   4            COUNT FEMALE        4.8        NaN        NaN        NaN
# 4   5          PERCENT FEMALE      0.404        NaN        NaN        NaN
# 5   6              COUNT MALE        4.6        NaN        NaN        NaN
# 6   7            PERCENT MALE      0.396        NaN        NaN        NaN
# 7   8    COUNT GENDER UNKNOWN          0        NaN        NaN        NaN
# 8   9  PERCENT GENDER UNKNOWN          0        NaN        NaN        NaN
# 9  10      COUNT GENDER TOTAL        9.4        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# ...

# %%
df
# Out:
#      0                   Average Statistics          Unnamed: 2    Unnamed: 3  \
# 0    1                                  NaN                   0           NaN
# 1    2                    JURISDICTION NAME             10005.8           NaN
# 2    3                   COUNT PARTICIPANTS                 9.4           NaN
# 3    4                         COUNT FEMALE                 4.8           NaN
# 4    5                       PERCENT FEMALE               0.404           NaN
# 5    6                           COUNT MALE                 4.6           NaN
# 6    7                         PERCENT MALE               0.396           NaN
# 7    8                 COUNT GENDER UNKNOWN                   0           NaN
# 8    9               PERCENT GENDER UNKNOWN                   0           NaN
# 9   10                   COUNT GENDER TOTAL                 9.4           NaN
# 10  11                 PERCENT GENDER TOTAL                  80           NaN
# ...

# %%
# Print the last 5 rows of df
df.tail()
# Out:
#      0 Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 52  53              10006          6          2       0.33          4
# 53  54              10007          1          0          0          1
# 54  55              10009          2          0          0          2
# 55  56              10010          0          0          0          0
# 56  57              10011          3          2       0.67          1
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 37 Unnamed: 38  \
# 52       0.67          0          0          6  ...           6         100
# 53          1          0          0          1  ...           1         100
# 54          1          0          0          2  ...           2         100
# 55          0          0          0          0  ...           0           0
# 56       0.33          0          0          3  ...           3         100
#
#    Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43 Unnamed: 44  \
# ...

# %%
# What is going on with this data set? Anything unusual?
# The first rows have a lot of blank values

# %%
# Clean up the dataset
df2 = pd.read_csv('./Data/Zipcode_Demos.csv', header=47)

# %%
df2 = df2.drop(['47'],axis=1)

# %% [markdown]
# ## Level Up (Optional) - Loading Corrupt CSV files
#
# Occasionally, you encounter some really ill-formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and the commas within those fields themselves. For example, we could have a table like this:
#
# `ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restaurant was pretty good, we had a great time.,98765`
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# `"ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restaurant was pretty good, we had a great time.","98765"`
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled `'Yelp_Reviews_Corrupt.csv'`. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-9a86fe410c83> in <module>
# ----> 1 pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
file_obj = open('./Data/Yelp_Reviews_Corrupt.csv')

# %%
file_contents = file_obj.readlines()

# %%
df_yelp = pd.DataFrame(open('./Data/Yelp_Reviews_Corrupt.csv').readlines())

# %%
df_yelp.head()
# Out:
#                                                    0
# 0  ,business_id,cool,date,funny,review_id,stars,t...
# 1  1,pomGBqfbxcqPv14c3XH-ZQ,0,2012-11-13,0,dDl8zu...
# 2  2,jtQARsP6P-LbkyjbO1qNGg,1,2014-10-23,1,LZp4UX...
# 3  4,Ums3gaP2qM3W1XcA5r6SsQ,0,2014-09-05,0,jsDu6Q...
# 4  5,vgfcTvK81oD4r50NMjU2Ag,0,2011-02-25,0,pfavA0...

# %%
test_list = []

for index, row in enumerate(open('./Data/Yelp_Reviews_Corrupt.csv').readline()):
    try:
        if not index:
            df_yelp = row
        else:
            df = df.append(row)
    except ParserError:
        continue
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4831744201c9> in <module>
#       4             df_yelp = row
#       5         else:
# ----> 6             df = df.append(row)
#       7     except ParserError:
#       8         continue
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
# ...

# %%
try:
    df_yelp = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
except ParserError:
    pass

# %%
df_yelp
# Out:
#                                                       0
# 0     ,business_id,cool,date,funny,review_id,stars,t...
# 1     1,pomGBqfbxcqPv14c3XH-ZQ,0,2012-11-13,0,dDl8zu...
# 2     2,jtQARsP6P-LbkyjbO1qNGg,1,2014-10-23,1,LZp4UX...
# 3     4,Ums3gaP2qM3W1XcA5r6SsQ,0,2014-09-05,0,jsDu6Q...
# 4     5,vgfcTvK81oD4r50NMjU2Ag,0,2011-02-25,0,pfavA0...
# ...                                                 ...
# 6104                                                 \n
# 6105  Finally - Food was mediocre. I was extremely d...
# 6106                                                 \n
# 6107  Wasn't worth the hype, unfortunately.,1,PkRFSQ...
# 6108  4206,WdBWhGe4Siqg3IYTc4_K4A,0,2016-08-15,0,O0t...
#
# [6109 rows x 1 columns]

# %%
# Hint: Here's a useful programming pattern to use
try:
    df_yelp = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
except Exception as e:
    df_yelp = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv', skiprows = 7000)

# %%
df_yelp

# %% [markdown]
# ## Summary
#
# Congratulations, you now practiced your Pandas-importing skills!
